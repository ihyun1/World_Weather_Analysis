# %%
# Import the dependencies.
import pandas as pd
import numpy as np

from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print('Beginning Data Retrieval       ')
print('-------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + '&q=' + city.replace(' ','+')
    
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                         'Country': city_country,
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Current Description': city_description})
        
# If an error is experienced, skip the city.
    except:
        print('City not found. Skipping...')
        pass

# Indicate that Dat Loading is complete.
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | salalah
# Processing Record 2 of Set 1 | ambilobe
# Processing Record 3 of Set 1 | whitehorse
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | palmer
# Processing Record 6 of Set 1 | bata
# Processing Record 7 of Set 1 | bubaque
# Processing Record 8 of Set 1 | aklavik
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | inuvik
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | perth
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | weligama
# Processing Record 16 of Set 1 | sabha
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | uren
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | vostok
# Processing Record 28 of Set 1 | kulhudhuffushi
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | zvishavane
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | keningau
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | doha
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | vardo
# Processing Record 39 of Set 1 | santiago del estero
# Processing Record 40 of Set 1 | lephepe
# City not found. Skipping...
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | vila velha
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | lastoursville
# Processing Record 45 of Set 1 | san cristobal
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | buala
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | tazovskiy
# Processing Record 50 of Set 1 | half moon bay
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | portland
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | rosaryville
# Processing Record 8 of Set 2 | nanortalik
# Processing Record 9 of Set 2 | harper
# Processing Record 10 of Set 2 | deputatskiy
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | karratha
# Processing Record 13 of Set 2 | limoux
# Processing Record 14 of Set 2 | ust-maya
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | kraslava
# Processing Record 18 of Set 2 | dossor
# Processing Record 19 of Set 2 | grand gaube
# Processing Record 20 of Set 2 | maloh
# Processing Record 21 of Set 2 | itoman
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | port hardy
# Processing Record 24 of Set 2 | daru
# Processing Record 25 of Set 2 | te anau
# Processing Record 26 of Set 2 | constitucion
# Processing Record 27 of Set 2 | richards bay
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | necochea
# Processing Record 30 of Set 2 | dibaya
# City not found. Skipping...
# Processing Record 31 of Set 2 | nouadhibou
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | galesong
# Processing Record 34 of Set 2 | isla aguada
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | ugoofaaru
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | ouallam
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | la palma
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | karonga
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | bouna
# Processing Record 47 of Set 2 | kibala
# Processing Record 48 of Set 2 | lata
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | vychegodskiy
# Processing Record 1 of Set 3 | caconda
# Processing Record 2 of Set 3 | sibolga
# Processing Record 3 of Set 3 | dali
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | athabasca
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | gat
# Processing Record 8 of Set 3 | tautira
# Processing Record 9 of Set 3 | iralaya
# Processing Record 10 of Set 3 | marshall
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | mareeba
# Processing Record 13 of Set 3 | nalut
# Processing Record 14 of Set 3 | souris
# Processing Record 15 of Set 3 | tecoanapa
# Processing Record 16 of Set 3 | esmeraldas
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | kahului
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | mehamn
# Processing Record 21 of Set 3 | barao de melgaco
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | pisco
# Processing Record 24 of Set 3 | san policarpo
# Processing Record 25 of Set 3 | san patricio
# Processing Record 26 of Set 3 | boldva
# Processing Record 27 of Set 3 | dingle
# Processing Record 28 of Set 3 | rio grande
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | sisimiut
# Processing Record 31 of Set 3 | esperance
# Processing Record 32 of Set 3 | kuah
# Processing Record 33 of Set 3 | kasongo-lunda
# Processing Record 34 of Set 3 | saint-raymond
# Processing Record 35 of Set 3 | anadyr
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | bo rai
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | yumen
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | along
# Processing Record 42 of Set 3 | calvinia
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | barra do garcas
# Processing Record 45 of Set 3 | moen
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | raudeberg
# Processing Record 48 of Set 3 | bathsheba
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | alappuzha
# Processing Record 1 of Set 4 | interlaken
# Processing Record 2 of Set 4 | tupaciguara
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | bilibino
# Processing Record 5 of Set 4 | tuktoyaktuk
# Processing Record 6 of Set 4 | iwanai
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | nuevo progreso
# Processing Record 9 of Set 4 | moose factory
# Processing Record 10 of Set 4 | antalaha
# Processing Record 11 of Set 4 | flin flon
# Processing Record 12 of Set 4 | kapaa
# Processing Record 13 of Set 4 | lavrentiya
# Processing Record 14 of Set 4 | baoding
# Processing Record 15 of Set 4 | springbok
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | bukachacha
# Processing Record 18 of Set 4 | hearst
# Processing Record 19 of Set 4 | finschhafen
# Processing Record 20 of Set 4 | high level
# Processing Record 21 of Set 4 | lodja
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | klaksvik
# Processing Record 24 of Set 4 | luena
# Processing Record 25 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 4 | codrington
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | queanbeyan
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | souillac
# Processing Record 31 of Set 4 | acapulco
# Processing Record 32 of Set 4 | hue
# Processing Record 33 of Set 4 | darnah
# Processing Record 34 of Set 4 | sobolevo
# Processing Record 35 of Set 4 | westport
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | bondo
# Processing Record 39 of Set 4 | guerrero negro
# Processing Record 40 of Set 4 | saint george
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | ghanzi
# Processing Record 43 of Set 4 | portobelo
# Processing Record 44 of Set 4 | cherskiy
# Processing Record 45 of Set 4 | makurdi
# Processing Record 46 of Set 4 | kaura namoda
# Processing Record 47 of Set 4 | manaus
# Processing Record 48 of Set 4 | povenets
# Processing Record 49 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | mandali
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | stokmarknes
# Processing Record 3 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 5 | milingimbi
# City not found. Skipping...
# Processing Record 5 of Set 5 | grindavik
# Processing Record 6 of Set 5 | henties bay
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | aykino
# Processing Record 9 of Set 5 | olinda
# Processing Record 10 of Set 5 | cotonou
# Processing Record 11 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 5 | sola
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | akyab
# Processing Record 16 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 5 | san juan del sur
# Processing Record 18 of Set 5 | olafsvik
# Processing Record 19 of Set 5 | mudanya
# Processing Record 20 of Set 5 | cabo san lucas
# Processing Record 21 of Set 5 | avera
# Processing Record 22 of Set 5 | neiafu
# Processing Record 23 of Set 5 | yeppoon
# Processing Record 24 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 5 | emerald
# Processing Record 26 of Set 5 | pedasi
# Processing Record 27 of Set 5 | omsukchan
# Processing Record 28 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 29 of Set 5 | urumqi
# Processing Record 30 of Set 5 | bow island
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | severo-kurilsk
# Processing Record 33 of Set 5 | eureka
# Processing Record 34 of Set 5 | nisia floresta
# Processing Record 35 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 5 | tapes
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | sokoto
# Processing Record 39 of Set 5 | preobrazheniye
# Processing Record 40 of Set 5 | mackay
# Processing Record 41 of Set 5 | lagoa
# Processing Record 42 of Set 5 | kodiak
# Processing Record 43 of Set 5 | egvekinot
# Processing Record 44 of Set 5 | saint-ambroise
# Processing Record 45 of Set 5 | alice springs
# Processing Record 46 of Set 5 | goba
# Processing Record 47 of Set 5 | praia da vitoria
# Processing Record 48 of Set 5 | cervo
# Processing Record 49 of Set 5 | rovnoye
# Processing Record 50 of Set 5 | kulebaki
# Processing Record 1 of Set 6 | tanete
# Processing Record 2 of Set 6 | cayenne
# Processing Record 3 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 6 | ipixuna
# Processing Record 5 of Set 6 | banda aceh
# Processing Record 6 of Set 6 | lamu
# Processing Record 7 of Set 6 | albesti
# Processing Record 8 of Set 6 | okakarara
# Processing Record 9 of Set 6 | devils lake
# Processing Record 10 of Set 6 | puerto madryn
# Processing Record 11 of Set 6 | gushikawa
# Processing Record 12 of Set 6 | kloulklubed
# Processing Record 13 of Set 6 | katobu
# Processing Record 14 of Set 6 | loreto
# Processing Record 15 of Set 6 | sorland
# Processing Record 16 of Set 6 | iqaluit
# Processing Record 17 of Set 6 | yuancheng
# Processing Record 18 of Set 6 | harlingen
# Processing Record 19 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 6 | piacabucu
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | akureyri
# Processing Record 23 of Set 6 | mahenge
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | poceirao
# Processing Record 26 of Set 6 | bichura
# Processing Record 27 of Set 6 | katsuura
# Processing Record 28 of Set 6 | auki
# Processing Record 29 of Set 6 | ribeira grande
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 6 | coihaique
# Processing Record 33 of Set 6 | mayo
# Processing Record 34 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 6 | hambantota
# Processing Record 36 of Set 6 | watrous
# Processing Record 37 of Set 6 | mizdah
# Processing Record 38 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 6 | mayya
# Processing Record 40 of Set 6 | malanje
# Processing Record 41 of Set 6 | pacific grove
# Processing Record 42 of Set 6 | lasa
# Processing Record 43 of Set 6 | orlik
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | ostrovnoy
# Processing Record 46 of Set 6 | erzin
# Processing Record 47 of Set 6 | scarborough
# Processing Record 48 of Set 6 | hami
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | juye
# Processing Record 1 of Set 7 | dalvik
# Processing Record 2 of Set 7 | awbari
# Processing Record 3 of Set 7 | podosinovets
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 6 of Set 7 | tabas
# Processing Record 7 of Set 7 | peniche
# Processing Record 8 of Set 7 | bardsir
# Processing Record 9 of Set 7 | sekudai
# Processing Record 10 of Set 7 | kozhva
# Processing Record 11 of Set 7 | yangambi
# Processing Record 12 of Set 7 | umarkot
# Processing Record 13 of Set 7 | ninghai
# Processing Record 14 of Set 7 | jalu
# Processing Record 15 of Set 7 | lorengau
# Processing Record 16 of Set 7 | el sauzal
# Processing Record 17 of Set 7 | dalbandin
# Processing Record 18 of Set 7 | miraflores
# Processing Record 19 of Set 7 | nakasongola
# Processing Record 20 of Set 7 | batagay-alyta
# Processing Record 21 of Set 7 | sao joao da barra
# Processing Record 22 of Set 7 | pravia
# Processing Record 23 of Set 7 | sayyan
# Processing Record 24 of Set 7 | harsin
# Processing Record 25 of Set 7 | warah
# Processing Record 26 of Set 7 | salinas
# Processing Record 27 of Set 7 | ossora
# Processing Record 28 of Set 7 | bure
# Processing Record 29 of Set 7 | varberg
# Processing Record 30 of Set 7 | boffa
# Processing Record 31 of Set 7 | ambagarh chauki
# Processing Record 32 of Set 7 | coahuayana
# Processing Record 33 of Set 7 | kankan
# Processing Record 34 of Set 7 | marzuq
# Processing Record 35 of Set 7 | atka
# City not found. Skipping...
# Processing Record 36 of Set 7 | kaitangata
# Processing Record 37 of Set 7 | trenggalek
# Processing Record 38 of Set 7 | bouca
# Processing Record 39 of Set 7 | klisura
# Processing Record 40 of Set 7 | sangar
# Processing Record 41 of Set 7 | khotiv
# Processing Record 42 of Set 7 | maturin
# Processing Record 43 of Set 7 | rio gallegos
# Processing Record 44 of Set 7 | chapaevsk
# Processing Record 45 of Set 7 | cockburn town
# Processing Record 46 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 7 | mecca
# Processing Record 48 of Set 7 | takoradi
# Processing Record 49 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 7 | fuerte
# Processing Record 1 of Set 8 | nanakuli
# Processing Record 2 of Set 8 | korla
# Processing Record 3 of Set 8 | asfi
# Processing Record 4 of Set 8 | gubkin
# Processing Record 5 of Set 8 | tura
# Processing Record 6 of Set 8 | charters towers
# Processing Record 7 of Set 8 | mokhsogollokh
# Processing Record 8 of Set 8 | laja
# Processing Record 9 of Set 8 | launceston
# Processing Record 10 of Set 8 | mombasa
# Processing Record 11 of Set 8 | tuatapere
# Processing Record 12 of Set 8 | dongsheng
# Processing Record 13 of Set 8 | college
# Processing Record 14 of Set 8 | zabolottya
# City not found. Skipping...
# Processing Record 15 of Set 8 | raymond
# Processing Record 16 of Set 8 | vallenar
# Processing Record 17 of Set 8 | deniliquin
# Processing Record 18 of Set 8 | sorata
# Processing Record 19 of Set 8 | chapais
# Processing Record 20 of Set 8 | danilov
# Processing Record 21 of Set 8 | kyabe
# Processing Record 22 of Set 8 | moranbah
# Processing Record 23 of Set 8 | chicama
# Processing Record 24 of Set 8 | luganville
# Processing Record 25 of Set 8 | ovruch
# Processing Record 26 of Set 8 | opunake
# Processing Record 27 of Set 8 | banjar
# Processing Record 28 of Set 8 | chaman
# Processing Record 29 of Set 8 | udachnyy
# Processing Record 30 of Set 8 | sivas
# Processing Record 31 of Set 8 | mangrol
# Processing Record 32 of Set 8 | kysyl-syr
# Processing Record 33 of Set 8 | surat thani
# Processing Record 34 of Set 8 | keshan
# City not found. Skipping...
# Processing Record 35 of Set 8 | vanimo
# Processing Record 36 of Set 8 | leningradskiy
# Processing Record 37 of Set 8 | neuquen
# Processing Record 38 of Set 8 | vung tau
# Processing Record 39 of Set 8 | tilichiki
# Processing Record 40 of Set 8 | gaziantep
# Processing Record 41 of Set 8 | arti
# Processing Record 42 of Set 8 | mgandu
# Processing Record 43 of Set 8 | perbaungan
# Processing Record 44 of Set 8 | tran
# Processing Record 45 of Set 8 | buckingham
# Processing Record 46 of Set 8 | la ronge
# Processing Record 47 of Set 8 | jardim
# Processing Record 48 of Set 8 | bereda
# Processing Record 49 of Set 8 | leo
# Processing Record 50 of Set 8 | smithers
# Processing Record 1 of Set 9 | pasan
# Processing Record 2 of Set 9 | ucluelet
# Processing Record 3 of Set 9 | sao felix do xingu
# Processing Record 4 of Set 9 | kieta
# Processing Record 5 of Set 9 | takanabe
# Processing Record 6 of Set 9 | touros
# Processing Record 7 of Set 9 | okhotsk
# Processing Record 8 of Set 9 | pozo colorado
# Processing Record 9 of Set 9 | ondjiva
# Processing Record 10 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 9 | flinders
# Processing Record 12 of Set 9 | cesis
# Processing Record 13 of Set 9 | nguru
# Processing Record 14 of Set 9 | disna
# Processing Record 15 of Set 9 | gimli
# Processing Record 16 of Set 9 | viloco
# Processing Record 17 of Set 9 | gamba
# Processing Record 18 of Set 9 | furth im wald
# Processing Record 19 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 20 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 21 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 9 | el dorado
# Processing Record 23 of Set 9 | north myrtle beach
# Processing Record 24 of Set 9 | biggar
# Processing Record 25 of Set 9 | quatre cocos
# Processing Record 26 of Set 9 | ayan
# Processing Record 27 of Set 9 | ahipara
# Processing Record 28 of Set 9 | moroni
# Processing Record 29 of Set 9 | khandagayty
# Processing Record 30 of Set 9 | marawi
# Processing Record 31 of Set 9 | poum
# Processing Record 32 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 9 | diffa
# Processing Record 34 of Set 9 | beidao
# Processing Record 35 of Set 9 | rome
# Processing Record 36 of Set 9 | wa
# City not found. Skipping...
# Processing Record 37 of Set 9 | margate
# Processing Record 38 of Set 9 | alta floresta
# Processing Record 39 of Set 9 | hasaki
# Processing Record 40 of Set 9 | san quintin
# Processing Record 41 of Set 9 | superior
# Processing Record 42 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 43 of Set 9 | kukmor
# Processing Record 44 of Set 9 | volovo
# Processing Record 45 of Set 9 | ixtapa
# Processing Record 46 of Set 9 | abu samrah
# Processing Record 47 of Set 9 | mortka
# Processing Record 48 of Set 9 | edd
# Processing Record 49 of Set 9 | am timan
# Processing Record 50 of Set 9 | trinidad
# Processing Record 1 of Set 10 | nunkini
# Processing Record 2 of Set 10 | broome
# Processing Record 3 of Set 10 | arman
# Processing Record 4 of Set 10 | airai
# Processing Record 5 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 10 | tawau
# Processing Record 7 of Set 10 | bandarbeyla
# Processing Record 8 of Set 10 | zhigansk
# Processing Record 9 of Set 10 | jambi
# Processing Record 10 of Set 10 | derzhavinsk
# Processing Record 11 of Set 10 | ust-omchug
# Processing Record 12 of Set 10 | aldan
# Processing Record 13 of Set 10 | den helder
# Processing Record 14 of Set 10 | longhua
# Processing Record 15 of Set 10 | tucuman
# Processing Record 16 of Set 10 | makakilo city
# Processing Record 17 of Set 10 | port hedland
# Processing Record 18 of Set 10 | oussouye
# Processing Record 19 of Set 10 | bowen
# Processing Record 20 of Set 10 | ponta delgada
# Processing Record 21 of Set 10 | qinhuangdao
# Processing Record 22 of Set 10 | miri
# Processing Record 23 of Set 10 | vranovice
# Processing Record 24 of Set 10 | gasa
# Processing Record 25 of Set 10 | tartagal
# Processing Record 26 of Set 10 | general roca
# Processing Record 27 of Set 10 | merced
# Processing Record 28 of Set 10 | tadine
# Processing Record 29 of Set 10 | vestmanna
# Processing Record 30 of Set 10 | rietavas
# Processing Record 31 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 32 of Set 10 | novocheremshansk
# Processing Record 33 of Set 10 | puqi
# Processing Record 34 of Set 10 | rab
# City not found. Skipping...
# Processing Record 35 of Set 10 | zeya
# Processing Record 36 of Set 10 | kavieng
# Processing Record 37 of Set 10 | goderich
# Processing Record 38 of Set 10 | alofi
# Processing Record 39 of Set 10 | rumford
# Processing Record 40 of Set 10 | umba
# Processing Record 41 of Set 10 | arroyo
# Processing Record 42 of Set 10 | kushima
# Processing Record 43 of Set 10 | sonepur
# Processing Record 44 of Set 10 | erenhot
# Processing Record 45 of Set 10 | phuket
# Processing Record 46 of Set 10 | pathein
# Processing Record 47 of Set 10 | saint-pierre
# Processing Record 48 of Set 10 | karpuninskiy
# City not found. Skipping...
# Processing Record 49 of Set 10 | torbay
# Processing Record 50 of Set 10 | danville
# Processing Record 1 of Set 11 | tevriz
# Processing Record 2 of Set 11 | tohana
# Processing Record 3 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 11 | talladega
# Processing Record 5 of Set 11 | bangsund
# Processing Record 6 of Set 11 | taoudenni
# Processing Record 7 of Set 11 | havre-saint-pierre
# Processing Record 8 of Set 11 | adra
# Processing Record 9 of Set 11 | biak
# Processing Record 10 of Set 11 | oyotun
# Processing Record 11 of Set 11 | boguchany
# Processing Record 12 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 14 of Set 11 | shache
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | botwood
# Processing Record 17 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 11 | san jose
# Processing Record 19 of Set 11 | altamira
# Processing Record 20 of Set 11 | roald
# Processing Record 21 of Set 11 | manoel urbano
# Processing Record 22 of Set 11 | puerto del rosario
# Processing Record 23 of Set 11 | bridlington
# Processing Record 24 of Set 11 | diglur
# Processing Record 25 of Set 11 | rincon
# Processing Record 26 of Set 11 | vernon
# Processing Record 27 of Set 11 | talnakh
# Processing Record 28 of Set 11 | baiyin
# Processing Record 29 of Set 11 | bastia
# Processing Record 30 of Set 11 | monteagudo
# Processing Record 31 of Set 11 | ndjole
# Processing Record 32 of Set 11 | itarema
# Processing Record 33 of Set 11 | nueve de julio
# Processing Record 34 of Set 11 | jalingo
# Processing Record 35 of Set 11 | caravelas
# Processing Record 36 of Set 11 | axim
# Processing Record 37 of Set 11 | kuryk
# Processing Record 38 of Set 11 | gangapur
# Processing Record 39 of Set 11 | husavik
# Processing Record 40 of Set 11 | mbanza-ngungu
# Processing Record 41 of Set 11 | nizhniy odes
# Processing Record 42 of Set 11 | port-gentil
# Processing Record 43 of Set 11 | fort-shevchenko
# Processing Record 44 of Set 11 | hofn
# Processing Record 45 of Set 11 | hasanabad
# Processing Record 46 of Set 11 | yulara
# Processing Record 47 of Set 11 | polunochnoye
# Processing Record 48 of Set 11 | hervey bay
# Processing Record 49 of Set 11 | severnoye
# Processing Record 50 of Set 11 | novovarshavka
# Processing Record 1 of Set 12 | lyubeshiv
# City not found. Skipping...
# Processing Record 2 of Set 12 | tortosa
# Processing Record 3 of Set 12 | skibbereen
# Processing Record 4 of Set 12 | solnechnyy
# Processing Record 5 of Set 12 | eenhana
# Processing Record 6 of Set 12 | saint-georges
# Processing Record 7 of Set 12 | nakamura
# Processing Record 8 of Set 12 | starozhilovo
# Processing Record 9 of Set 12 | outjo
# Processing Record 10 of Set 12 | viedma
# Processing Record 11 of Set 12 | karasburg
# Processing Record 12 of Set 12 | noumea
# Processing Record 13 of Set 12 | kasongo
# Processing Record 14 of Set 12 | acarau
# Processing Record 15 of Set 12 | havoysund
# Processing Record 16 of Set 12 | general pico
# Processing Record 17 of Set 12 | marienburg
# Processing Record 18 of Set 12 | mpongwe
# Processing Record 19 of Set 12 | el tigre
# Processing Record 20 of Set 12 | medak
# Processing Record 21 of Set 12 | ribeira brava
# Processing Record 22 of Set 12 | meulaboh
# Processing Record 23 of Set 12 | vao
# Processing Record 24 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 25 of Set 12 | ilhabela
# Processing Record 26 of Set 12 | cururupu
# Processing Record 27 of Set 12 | florianopolis
# Processing Record 28 of Set 12 | coari
# Processing Record 29 of Set 12 | kupang
# Processing Record 30 of Set 12 | nsoko
# Processing Record 31 of Set 12 | beringovskiy
# Processing Record 32 of Set 12 | mwinilunga
# Processing Record 33 of Set 12 | kasama
# Processing Record 34 of Set 12 | waipawa
# Processing Record 35 of Set 12 | nigde
# Processing Record 36 of Set 12 | plymouth
# Processing Record 37 of Set 12 | mbini
# Processing Record 38 of Set 12 | taybad
# Processing Record 39 of Set 12 | road town
# Processing Record 40 of Set 12 | komsomolskiy
# Processing Record 41 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 12 | manzhouli
# Processing Record 43 of Set 12 | asnaes
# Processing Record 44 of Set 12 | synya
# Processing Record 45 of Set 12 | edgewater
# Processing Record 46 of Set 12 | safranbolu
# Processing Record 47 of Set 12 | ramos arizpe
# Processing Record 48 of Set 12 | marystown
# Processing Record 49 of Set 12 | niksar
# Processing Record 50 of Set 12 | lyndon
# Processing Record 1 of Set 13 | eregli
# Processing Record 2 of Set 13 | victor harbor
# Processing Record 3 of Set 13 | kalanguy
# Processing Record 4 of Set 13 | tigil
# Processing Record 5 of Set 13 | shkotovo-22
# City not found. Skipping...
# Processing Record 6 of Set 13 | kiama
# Processing Record 7 of Set 13 | muroto
# Processing Record 8 of Set 13 | praya
# Processing Record 9 of Set 13 | sambava
# Processing Record 10 of Set 13 | honiara
# Processing Record 11 of Set 13 | madang
# Processing Record 12 of Set 13 | sawang daen din
# Processing Record 13 of Set 13 | brownwood
# Processing Record 14 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 15 of Set 13 | ust-kulom
# Processing Record 16 of Set 13 | kerouane
# Processing Record 17 of Set 13 | valdivia
# Processing Record 18 of Set 13 | mnogovershinnyy
# Processing Record 19 of Set 13 | byron bay
# Processing Record 20 of Set 13 | tuchkovo
# Processing Record 21 of Set 13 | kita
# Processing Record 22 of Set 13 | angoram
# Processing Record 23 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 13 | tatawin
# Processing Record 25 of Set 13 | matara
# Processing Record 26 of Set 13 | zhigalovo
# Processing Record 27 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 13 | dunedin
# Processing Record 29 of Set 13 | leh
# Processing Record 30 of Set 13 | yuksekova
# Processing Record 31 of Set 13 | greytown
# Processing Record 32 of Set 13 | saint-lo
# Processing Record 33 of Set 13 | upington
# Processing Record 34 of Set 13 | bilgi
# Processing Record 35 of Set 13 | hinundayan
# Processing Record 36 of Set 13 | jamame
# Processing Record 37 of Set 13 | naryan-mar
# Processing Record 38 of Set 13 | luanda
# Processing Record 39 of Set 13 | gbarnga
# Processing Record 40 of Set 13 | utrera
# Processing Record 41 of Set 13 | mount isa
# Processing Record 42 of Set 13 | khani
# Processing Record 43 of Set 13 | soto la marina
# Processing Record 44 of Set 13 | dustlik
# Processing Record 45 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 13 | altay
# Processing Record 47 of Set 13 | dothan
# Processing Record 48 of Set 13 | los llanos de aridane
# Processing Record 49 of Set 13 | stornoway
# Processing Record 50 of Set 13 | gladstone
# Processing Record 1 of Set 14 | dwarka
# Processing Record 2 of Set 14 | katangli
# Processing Record 3 of Set 14 | pak chong
# Processing Record 4 of Set 14 | saint anthony
# Processing Record 5 of Set 14 | berdigestyakh
# Processing Record 6 of Set 14 | sioux lookout
# Processing Record 7 of Set 14 | tagusao
# Processing Record 8 of Set 14 | la rioja
# Processing Record 9 of Set 14 | sibu
# Processing Record 10 of Set 14 | burns lake
# Processing Record 11 of Set 14 | laerdalsoyri
# Processing Record 12 of Set 14 | progreso
# Processing Record 13 of Set 14 | saurimo
# Processing Record 14 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 14 | yueyang
# Processing Record 16 of Set 14 | nizhniy ingash
# Processing Record 17 of Set 14 | susehri
# Processing Record 18 of Set 14 | ilorin
# Processing Record 19 of Set 14 | krasnoborsk
# Processing Record 20 of Set 14 | magadan
# Processing Record 21 of Set 14 | vigrestad
# Processing Record 22 of Set 14 | santa isabel do rio negro
# Processing Record 23 of Set 14 | mustasaari
# Processing Record 24 of Set 14 | shelburne
# Processing Record 25 of Set 14 | mujiayingzi
# Processing Record 26 of Set 14 | brisbane
# Processing Record 27 of Set 14 | vredendal
# Processing Record 28 of Set 14 | gubkinskiy
# Processing Record 29 of Set 14 | gashua
# Processing Record 30 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 14 | tabou
# Processing Record 32 of Set 14 | clarence town
# Processing Record 33 of Set 14 | saint-malo
# Processing Record 34 of Set 14 | wellington
# Processing Record 35 of Set 14 | port hawkesbury
# Processing Record 36 of Set 14 | hofu
# Processing Record 37 of Set 14 | spasskoye
# Processing Record 38 of Set 14 | benxi
# Processing Record 39 of Set 14 | rehoboth
# Processing Record 40 of Set 14 | havelock
# Processing Record 41 of Set 14 | riohacha
# Processing Record 42 of Set 14 | kastamonu
# Processing Record 43 of Set 14 | belaya kholunitsa
# Processing Record 44 of Set 14 | seredka
# Processing Record 45 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 14 | huron
# Processing Record 47 of Set 14 | bogale
# Processing Record 48 of Set 14 | rongcheng
# Processing Record 49 of Set 14 | buraydah
# Processing Record 50 of Set 14 | tirlyanskiy
# Processing Record 1 of Set 15 | bestobe
# Processing Record 2 of Set 15 | pringsewu
# Processing Record 3 of Set 15 | podor
# Processing Record 4 of Set 15 | la baule-escoublac
# Processing Record 5 of Set 15 | yenagoa
# Processing Record 6 of Set 15 | kavaratti
# Processing Record 7 of Set 15 | wanning
# Processing Record 8 of Set 15 | teya
# Processing Record 9 of Set 15 | male
# Processing Record 10 of Set 15 | mahajanga
# Processing Record 11 of Set 15 | zhuanghe
# Processing Record 12 of Set 15 | medicine hat
# Processing Record 13 of Set 15 | ancud
# Processing Record 14 of Set 15 | sigli
# Processing Record 15 of Set 15 | mount forest
# Processing Record 16 of Set 15 | port lincoln
# Processing Record 17 of Set 15 | craig
# Processing Record 18 of Set 15 | isangel
# Processing Record 19 of Set 15 | ambulu
# Processing Record 20 of Set 15 | trincomalee
# Processing Record 21 of Set 15 | ulladulla
# Processing Record 22 of Set 15 | kungurtug
# Processing Record 23 of Set 15 | pinhao
# Processing Record 24 of Set 15 | strezhevoy
# Processing Record 25 of Set 15 | zalantun
# Processing Record 26 of Set 15 | dong xoai
# Processing Record 27 of Set 15 | samarai
# Processing Record 28 of Set 15 | praia
# Processing Record 29 of Set 15 | sompeta
# Processing Record 30 of Set 15 | maunabo
# Processing Record 31 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 32 of Set 15 | badou
# Processing Record 33 of Set 15 | pemangkat
# Processing Record 34 of Set 15 | fukue
# Processing Record 35 of Set 15 | kurgunta
# Processing Record 36 of Set 15 | qinzhou
# Processing Record 37 of Set 15 | dasoguz
# Processing Record 38 of Set 15 | mount gambier
# Processing Record 39 of Set 15 | jeremie
# Processing Record 40 of Set 15 | turukhansk
# Processing Record 41 of Set 15 | santander
# Processing Record 42 of Set 15 | osterburg
# Processing Record 43 of Set 15 | inhambane
# Processing Record 44 of Set 15 | fort pierce
# Processing Record 45 of Set 15 | ekhabi
# Processing Record 46 of Set 15 | chara
# Processing Record 47 of Set 15 | naron
# Processing Record 48 of Set 15 | zaozerne
# Processing Record 49 of Set 15 | evensk
# Processing Record 50 of Set 15 | bucerias
# Processing Record 1 of Set 16 | rognan
# Processing Record 2 of Set 16 | casper
# Processing Record 3 of Set 16 | cardston
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
len(city_data)
# Out:
# 696

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Salalah      OM  17.02   54.09     77.00        94          90
# 1        Ambilobe      MG -13.20   49.05     76.06        61           0
# 2      Whitehorse      CA  60.72 -135.05     46.40        93          75
# 3    Punta Arenas      CL -53.15  -70.92     37.40        86          75
# 4          Palmer      US  42.16  -72.33     70.00       100          90
# ..            ...     ...    ...     ...       ...       ...         ...
# 691        Evensk      RU  61.95  159.23     47.03        72          59
# 692      Bucerias      MX  20.75 -105.33     79.00        88          75
# 693        Rognan      NO  67.10   15.39     54.00        77          94
# 694        Casper      US  42.87 -106.31     55.99        71           1
# 695      Cardston      CA  49.20 -113.30     62.01        41          75
#
#      Wind Speed          Current Description
# 0          5.82              overcast clouds
# 1          0.60                    clear sky
# 2          4.70                   light rain
# 3         16.11  light intensity shower rain
# 4          2.62                moderate rain
# ..          ...                          ...
# 691       12.08                broken clouds
# 692        6.93                broken clouds
# 693        6.26              overcast clouds
# 694        5.82                    clear sky
# 695        8.05                broken clouds
#
# [696 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
